# %% [markdown]
# # Ax Capability Demo Index
#
# These notebooks are external demos for Ax features you asked about. They are
# designed for your current environment, not Ax 1.x docs.
#
# Recommended interpreter:
# - `C:\Users\aisci\AppData\Local\Programs\Python\Python311\python.exe`
#
# Notebook map:
#
# | Notebook | What it shows | Expected status in your current env |
# | --- | --- | --- |
# | `01_outcome_constraints_status_quo.ipynb` | Outcome constraints + baseline/status quo | Runnable |
# | `02_tracking_metrics.ipynb` | Tracking metrics separate from optimization objective | Runnable |
# | `03_objective_thresholds_pareto.ipynb` | Objective thresholds for multi-objective/Pareto mode | Runnable |
# | `04_early_stopping_progression.ipynb` | Early stopping using intermediate progression data | Runnable |
# | `05_external_generation_node_mock_llm.ipynb` | ExternalGenerationNode as a stand-in for an LLM policy | Runnable |
# | `06_scheduler_and_sql_storage.ipynb` | Scheduler demo + SQL storage readiness check | Scheduler runnable, SQL storage gated |

# %%
import sys
import importlib.metadata as md

packages = [
        "ax-platform",
        "botorch",
        "torch",
        "pandas",
        "matplotlib",
        "SQLAlchemy",
    ]

print("Python executable:", sys.executable)
print("Python version:", sys.version)
for package in packages:
        try:
            print(f"{package}: {md.version(package)}")
        except md.PackageNotFoundError:
            print(f"{package}: not installed")

print("Recommended interpreter:")
print(r"C:\Users\aisci\AppData\Local\Programs\Python\Python311\python.exe")
# Out:
# Python executable: c:\Users\aisci\AppData\Local\Programs\Python\Python311\python.exe
# Python version: 3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]
# ax-platform: 0.4.3
# botorch: 0.16.1
# torch: 2.10.0
# pandas: 2.2.3
# matplotlib: 3.9.2
# SQLAlchemy: 2.0.45
# Recommended interpreter:
# C:\Users\aisci\AppData\Local\Programs\Python\Python311\python.exe

# %% [markdown]
# ## What To Look For
#
# 1. `01`: how Ax stores a `status_quo` and how relative outcome constraints are represented.
# 2. `02`: how extra metrics can be stored without becoming optimization objectives.
# 3. `03`: how objective thresholds define the region of interest in multi-objective optimization.
# 4. `04`: how progression data enables early-stop decisions.
# 5. `05`: how an external policy can generate candidates while Ax still manages experiment state.
# 6. `06`: how closed-loop scheduling works in Ax 0.4.3 and why SQL storage is currently disabled in your env.
